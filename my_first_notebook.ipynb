# %% [markdown]
# what we have to feel physically that calls hardware. example: cpu, keyboar and mouse.
#
# what we can't touch and feel physically that calls software it will work to build using such code. example: windows and apps.
